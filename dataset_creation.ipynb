# %%
import numpy as np
import pandas as pd

# %%
cd FOT
# Out:
# [WinError 2] The system cannot find the file specified: 'FOT'
# D:\FOT\sem 5\aiml\stock price prediction\dataset
# C:\Users\adity\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\magics\osm.py:393: UserWarning: using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})

# %%
ls
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is 485D-FF59
#
#  Directory of D:\FOT\sem 5\aiml\stock price prediction\dataset
#
# 29-10-2025  16:10    <DIR>          .
# 29-10-2025  16:12    <DIR>          ..
# 29-10-2025  16:07            40,571 reliance_1.csv
# 29-10-2025  16:08            40,487 reliance_2.csv
# 29-10-2025  16:08            40,146 reliance_3.csv
# 29-10-2025  16:09            40,323 reliance_4.csv
# 29-10-2025  16:10            40,238 reliance_5.csv
#                5 File(s)        201,765 bytes
#                2 Dir(s)  146,008,944,640 bytes free

# %%
df1 = pd.read_csv("reliance_1.csv")
df2 = pd.read_csv("reliance_2.csv")
df3 = pd.read_csv("reliance_3.csv")
df4 = pd.read_csv("reliance_4.csv")
df5 = pd.read_csv("reliance_5.csv")

# %%
df = pd.concat([df1,df2,df3,df4,df5])

# %%
df
# Out:
#            Date  series      OPEN      HIGH       LOW  PREV. CLOSE       ltp   \
# 0    28-Oct-2025      EQ  1,484.10  1,492.00  1,477.60     1,484.10  1,489.70
# 1    27-Oct-2025      EQ  1,463.00  1,485.00  1,458.00     1,451.60  1,483.20
# 2    24-Oct-2025      EQ  1,450.00  1,459.80  1,441.00     1,448.40  1,451.10
# 3    23-Oct-2025      EQ  1,475.00  1,482.90  1,444.60     1,465.20  1,448.00
# 4    21-Oct-2025      EQ  1,468.00  1,474.00  1,460.00     1,466.80  1,461.00
# ..           ...     ...       ...       ...       ...          ...       ...
# 243  04-Nov-2020      EQ  1,837.00  1,929.00  1,837.00     1,850.40  1,910.50
# 244  03-Nov-2020      EQ  1,890.00  1,909.00  1,835.10     1,877.45  1,854.50
# 245  02-Nov-2020      EQ  2,027.00  2,027.00  1,859.15     2,054.50  1,876.00
# 246  30-Oct-2020      EQ  2,033.50  2,065.10  2,021.80     2,026.90  2,064.35
# 247  29-Oct-2020      EQ  1,997.00  2,042.00  1,991.00     2,011.45  2,029.05
#
# ...

# %%
df.to_csv("reliance.csv")

# %%
df1 = pd.read_csv("tcs_1.csv")
df2 = pd.read_csv("tcs_2.csv")
df3 = pd.read_csv("tcs_3.csv")
df4 = pd.read_csv("tcs_4.csv")
df5 = pd.read_csv("tcs_5.csv")

# %%
df = pd.concat([df1,df2,df3,df4,df5])

# %%
df
# Out:
#            Date  series      OPEN      HIGH       LOW  PREV. CLOSE       ltp   \
# 0    28-Oct-2025      EQ  3,076.00  3,090.20  3,040.20     3,084.90  3,059.80
# 1    27-Oct-2025      EQ  3,066.50  3,094.20  3,060.20     3,063.20  3,083.00
# 2    24-Oct-2025      EQ  3,080.00  3,090.00  3,058.30     3,073.20  3,060.60
# 3    23-Oct-2025      EQ  3,055.00  3,098.00  3,036.10     3,006.70  3,070.00
# 4    21-Oct-2025      EQ  3,031.10  3,031.80  2,996.00     3,015.20  3,000.00
# ..           ...     ...       ...       ...       ...          ...       ...
# 244  04-Nov-2020      EQ  2,610.00  2,721.85  2,610.00     2,633.60  2,656.00
# 245  03-Nov-2020      EQ  2,604.00  2,665.00  2,601.05     2,604.60  2,629.00
# 246  02-Nov-2020      EQ  2,660.00  2,664.85  2,600.05     2,664.85  2,608.00
# 247  30-Oct-2020      EQ  2,636.10  2,674.35  2,621.60     2,632.65  2,663.55
# 248  29-Oct-2020      EQ  2,608.00  2,655.00  2,600.25     2,622.20  2,632.10
#
# ...

# %%
df.to_csv("tcs.csv")

# %%
df1 = pd.read_csv("itc_1.csv")
df2 = pd.read_csv("itc_2.csv")
df3 = pd.read_csv("itc_3.csv")
df4 = pd.read_csv("itc_4.csv")
df5 = pd.read_csv("itc_5.csv")

# %%
df = pd.concat([df1,df2,df3,df4,df5])

# %%
df
# Out:
#            Date  series    OPEN    HIGH     LOW   PREV. CLOSE     ltp   \
# 0    28-Oct-2025      EQ  420.50  421.65  415.90        420.65  417.85
# 1    27-Oct-2025      EQ  417.00  422.70  416.60        416.80  421.00
# 2    24-Oct-2025      EQ  415.95  417.95  413.45        415.95  417.80
# 3    23-Oct-2025      EQ  416.00  420.45  413.55        412.85  416.25
# 4    21-Oct-2025      EQ  413.50  413.95  412.35        413.05  412.50
# ..           ...     ...     ...     ...     ...           ...     ...
# 244  04-Nov-2020      EQ  170.05  171.80  168.20        170.10  169.75
# 245  03-Nov-2020      EQ  167.20  170.75  167.10        166.75  170.00
# 246  02-Nov-2020      EQ  166.80  167.20  164.45        165.25  166.75
# 247  30-Oct-2020      EQ  164.00  166.80  163.35        163.85  165.40
# 248  29-Oct-2020      EQ  165.00  165.95  163.45        165.50  163.85
#
#      close    vwap   52W H   52W L       VOLUME               VALUE   \
# ...

# %%
df.to_csv("itc.csv")

# %%
df1 = pd.read_csv("hdfc_1.csv")
df2 = pd.read_csv("hdfc_2.csv")
df3 = pd.read_csv("hdfc_3.csv")
df4 = pd.read_csv("hdfc_4.csv")
df5 = pd.read_csv("hdfc_5.csv")

# %%
df = pd.concat([df1,df2,df3,df4,df5])

# %%
df
# Out:
#            Date  series      OPEN      HIGH       LOW  PREV. CLOSE       ltp   \
# 0    28-Oct-2025      EQ    997.65  1,008.00    995.00     1,002.95  1,004.90
# 1    27-Oct-2025      EQ    996.50  1,009.05    996.20       994.75  1,003.50
# 2    24-Oct-2025      EQ  1,011.00  1,011.95    991.30     1,008.80    995.90
# 3    23-Oct-2025      EQ  1,016.00  1,020.50  1,006.00     1,007.70  1,006.60
# 4    21-Oct-2025      EQ  1,006.00  1,010.00  1,004.00     1,002.95  1,004.00
# ..           ...     ...       ...       ...       ...          ...       ...
# 244  04-Nov-2020      EQ  1,252.00  1,264.80  1,230.00     1,247.95  1,254.00
# 245  03-Nov-2020      EQ  1,226.45  1,250.75  1,225.50     1,215.25  1,248.00
# 246  02-Nov-2020      EQ  1,194.35  1,225.00  1,177.50     1,183.55  1,216.25
# 247  30-Oct-2020      EQ  1,182.55  1,199.30  1,176.35     1,187.20  1,182.40
# 248  29-Oct-2020      EQ  1,200.60  1,204.45  1,178.50     1,209.60  1,190.50
#
# ...

# %%
df.to_csv("hdfc.csv")

# %%
df1 = pd.read_csv("mnm1.csv")
df2 = pd.read_csv("mnm2.csv")
df3 = pd.read_csv("mnm3.csv")
df4 = pd.read_csv("mnm4.csv")
df5 = pd.read_csv("mnm5.csv")

# %%
df = pd.concat([df1,df2,df3,df4,df5])

# %%
df
# Out:
#            Date  series      OPEN      HIGH       LOW  PREV. CLOSE       ltp   \
# 0    28-Oct-2025      EQ  3,605.00  3,624.90  3,562.00     3,611.60  3,581.00
# 1    27-Oct-2025      EQ  3,626.80  3,635.30  3,593.00     3,625.00  3,616.00
# 2    24-Oct-2025      EQ  3,630.00  3,655.30  3,615.10     3,623.60  3,618.20
# 3    23-Oct-2025      EQ  3,632.10  3,650.00  3,600.00     3,621.20  3,627.50
# 4    21-Oct-2025      EQ  3,608.20  3,628.10  3,604.30     3,599.10  3,606.00
# ..           ...     ...       ...       ...       ...          ...       ...
# 244  04-Nov-2020      EQ     597.8    603.65     592.0        595.8     597.2
# 245  03-Nov-2020      EQ     599.3    605.45     594.0       596.05     597.0
# 246  02-Nov-2020      EQ     592.0     599.9     589.0        594.0     594.0
# 247  30-Oct-2020      EQ    592.55    601.75     586.8       591.95    594.75
# 248  29-Oct-2020      EQ     598.2    604.15    590.25       604.15     592.5
#
# ...

# %%
df.to_csv("mnm.csv")
